# %%
import pandas as pd
from pandas.core.common import random_state
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
data = pd.read_csv('../assets/diabetes.csv')
data.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
X_train, X_test, Y_train, Y_test = train_test_split(data.drop("Outcome", axis=1), data["Outcome"], test_size=0.3, random_state=0)
X_train.shape, X_test.shape
# Out:
# ((537, 8), (231, 8))

# %%
scaler = StandardScaler()
scaler.fit(X_train)
X_train_scaled = scaler.transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
scaler.mean_
# Out:
# array([  3.8547486 , 121.54376164,  69.66666667,  21.03165736,
#         84.90130354,  32.25512104,   0.4713203 ,  33.67039106])

# %%
X_train
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 580            0      151             90             46        0  42.1
# 418            1       83             68              0        0  18.2
# 764            2      122             70             27        0  36.8
# 363            4      146             78              0        0  38.5
# 757            0      123             72              0        0  36.3
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 192            7      159             66              0        0  30.4
# 629            4       94             65             22        0  24.7
# 559           11       85             74              0        0  30.1
# 684            5      136             82              0        0   0.0
#
#      DiabetesPedigreeFunction  Age
# 580                     0.371   21
# 418                     0.624   27
# 764                     0.340   27
# 363                     0.520   67
# 757                     0.258   52
# ..                        ...  ...
# 763                     0.171   63
# 192                     0.383   36
# 629                     0.148   21
# 559                     0.300   35
# 684                     0.640   69
#
# [537 rows x 8 columns]
